# %%
my_dict={'Name':'ABC','Division':10,'Rollno':31,'Age':20,'Grade':'A+'}

#Add info
my_dict['City']='Kochi'
#Delete info
del my_dict['Age']
#Display info 
print(my_dict)
# Out:
# {'Name': 'Manav', 'Division': 10, 'Rollno': 31, 'Grade': 'A+', 'City': 'Kochi'}

# %%
l1=['name','division','rollno']
l2=['ABC','10',31]
my_dict={}
for i in range(len(l1)):
    my_dict[l1[i]]=l2[i]
print(my_dict)
# Out:
# {'name': 'ABC', 'division': '10', 'rollno': 31}

# %%
my_dict={'name':'ABC','panel':'B','rollno':34,'marks':[65,87,67,94]}
sorted(my_dict)
# Out:
# ['marks', 'name', 'panel', 'rollno']

# %%
my_dict={'name':'ABC','division':'10','rollno':31}
l1=my_dict.keys()
l2=my_dict.values()
print(l1)
print(l2)
# Out:
# dict_keys(['name', 'division', 'rollno'])
# dict_values(['ABC', '10', 31])

# %%
my_dict={'marks1':23,'marks2':67,'marks3':123,'marks4':43,'marks5':39}
Tsum=sum(my_dict.values())
l=len(my_dict)
X=Tsum/l
print("Mean=",X)
# Out:
# Mean= 59.0

# %%
my_dict={'name':['Yash','Neel','Dev'],'rollno':[11,12,13],'marks':[78,56,98]}
#display name as dev
print(my_dict['name'][2])
#display 12 roll no
print(my_dict['rollno'][1])
#display greatest marks
print(max(my_dict['marks']))
# Out:
# Dev
# 12
# 98

# %%
#frequency of letters
S=input("Enter word to count frequency of letters in")
for ch in set(S):
    print(ch,':',S.count(ch))
# Out:
# Enter word to count frequency of letters in hello
# o : 1
# e : 1
# l : 2
# h : 1

# %%
num=int(input("Enter numerator"))
den=int(input("Enter denominator"))
result=(num//den,num%den)
print(result)
# Out:
# Enter numerator 25
# Enter denominator 4
# (6, 1)

# %%
from datetime import date
d1=int(input('Day 1:'))
m1=int(input("Month 1:"))
y1=int(input("Year 1"))
d2=int(input('Day 2:'))
m2=int(input("Month 2:"))
y2=int(input("Year 2:"))

date1=date(y1,m1,d1)
date2=date(y2,m2,d2)

days=abs((date2-date1).days)
print("Days between dates=",days)
# Out:
# Day 1: 18
# Month 1: 11
# Year 1 2008
# Day 2: 15
# Month 2: 2
# Year 2: 2006
# Days between dates= 1007
